# %% [markdown]
# # Part II - Characterizations of Ford GoBike Users
# ## by Harry Edelman

# %% [markdown]
# ## Investigation Overview
# In this investigation, I'd like to explore what significant influences there are on total ride duration and distance (per trip and overall). For example, user type, age or gender, originating or terminating rental stations all might influence duration and distances of rides.
#
# ## Summary of Findings
# The main exploratory concept I wanted to focus on was to relate user types, genders, originating/terminating stations and age with distance and duration of rides. My initial expectation was that young male subscribers would ride the longest and farthest. Instead, young male subscribers turned out to represent the largest conglomerate of users, but didn't necessarily ride the farthest/longest.
#
# In general, both duration and distance data distributions were right-skewed with extreme outliers. Log-normalizing the duration data showed a mode of ~500 seconds per ride. Eliminating outliers for distance displays that the majority or rides were 2 km or less.
#
# The most frequent ages are in the late 20's through the mid 30's. Males represent nearly triple the users than females and other genders combined. Subscribers outnumber customers by nearly 8 times.
#
# Notable bivariate correlation pairs include the following:
# - start_station_id / end_station_id
# - start_station_longitude / end_station_longitude
# - start_station_latitude / end_station_latitude
# - start_station_latitude / end_station_longitude
# - start_station_longitude / end_station_latitude

# %% [markdown]
# ## Summary of Findings (cont'd)
# There turned out not to be a deep correlation between distance and duration, which was surprising. This must mean that there are a number of rentals that are not strictly for commuting purposes.
#
# Across the different age brackets, the medians, means and quartiles of duration and distance are not extraordinarily dissimilar. However, the age brackets from 21-60 all have disproportionate numbers of outliers.
#
# Finally, it appears that female and other gender have less concentration compared with males when it comes to distance and duration of bike rentals.
#
# ## Dataset Overview
# I used the Ford GoBike dataset. The source file was provided in CSV format, and contained 183,412 rows with 16 colums of data. The start and end-times were in string format, so I converted them to datetime for easier manipulation. Additionally, the birth year data was a float type where integers would be sifficient. I also added member age and distance between station columns based on member birth year and station coordinate data found in the source file. Finally, I excluded some age, distance and duration outliers that either seemed erroneous or were severely skewing the data for my analysis.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df_bikes_clean = pd.read_csv('bikeDataClean.csv')
df_bikes_clean['age_bracket'] = pd.Categorical(df_bikes_clean['age_bracket'], categories = ['0-10','11-20','21-30','31-40','41-50','51-60','61-70','71-80','81-90','91-100'],
                                               ordered=True)
clean_sample = df_bikes_clean.sample(n=500,replace=False)

# %% [markdown]
# > Note that the above cells have been set as "Skip"-type slides. That means
# that when the notebook is rendered as http slides, those cells won't show up.

# %% [markdown]
# ## Typical Ford Go Bike Users
# The majority of users are young male subscribers.

# %%
fig, ax = plt.subplots(ncols=3, figsize = [19,6])

default_color = sb.color_palette()[0]
fig.suptitle('User Characteristics',fontsize = 'x-large',fontweight = 'bold',y=0.92)
sb.countplot(data = df_bikes_clean, x = 'member_gender', color = default_color, ax = ax[0])
ax[0].set_xlabel("Gender",fontweight = 'bold')
ax[0].set_ylabel("Count",fontweight = 'bold')
sb.countplot(data = df_bikes_clean, x = 'user_type', color = default_color, ax = ax[1])
ax[1].set_xlabel("User Type",fontweight = 'bold')
ax[1].set_ylabel("Count",fontweight = 'bold')
sb.countplot(data = df_bikes_clean, x = 'age_bracket', color = default_color, ax = ax[2])
ax[2].set_xlabel("Age Bracket",fontweight = 'bold')
ax[2].set_ylabel("Count",fontweight = 'bold')
plt.show();

# %% [markdown]
# ## Distance vs Duration Surprisingly Uncorrelated
# Zooming in on distance vs duration shows there is surprisingly little influence of one variable on the other.

# %%
plt.figure(figsize = [8, 6])
plt.scatter(data = df_bikes_clean, x = 'distance_km', y = 'duration_sec', alpha = 1/10)
plt.xlim([0,7.5])
plt.xlabel('Distance (km)')
plt.ylabel('Duration (sec)')
plt.title('Distance vs Duration',fontweight = 'bold')
plt.show();

# %% [markdown]
# ## Similar Distributions Across Age Brackets
# Across the different age brackets, the medians, means and quartiles of duration and distance are not extraordinarily dissimilar. However, the age brackets from 21-60 all have disproportionate numbers of outliers.

# %%
fig, ax = plt.subplots(ncols = 1, nrows = 2 , figsize = [10,10])

ax = plt.subplot(2,1,1)
sb.violinplot(data=df_bikes_clean,x='age_bracket',y='duration_sec',color=sb.color_palette()[0])
ax.set_xlabel("Age Bracket",fontweight = 'bold')
ax.set_ylabel("Duration (sec)",fontweight = 'bold')
ax.set_title('Duration Distributed by Age',fontweight = 'bold')

ax = plt.subplot(2,1,2)
sb.violinplot(data=df_bikes_clean,x='age_bracket',y='distance_km',color=sb.color_palette()[0])
ax.set_xlabel("Age Bracket",fontweight = 'bold')
ax.set_ylabel("Distance (km)",fontweight = 'bold')
ax.set_title('Distance Distributed by Age',fontweight = 'bold');

# %%
# !jupyter nbconvert Part_II_Slide_Deck.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_Slide_Deck.ipynb to slides
# [NbConvertApp] Writing 778224 bytes to Part_II_Slide_Deck.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "C:\Users\img44\anaconda3\Scripts\jupyter-nbconvert-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\img44\anaconda3\lib\site-packages\jupyter_core\application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\Users\img44\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\img44\anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 346, in start
#     self.convert_notebooks()
#   File "C:\Users\img44\anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 518, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "C:\Users\img44\anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 485, in convert_single_notebook
#     self.postprocess_single_notebook(write_results)
#   File "C:\Users\img44\anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 457, in postprocess_single_notebook
#     self.postprocessor(write_results)
#   File "C:\Users\img44\anaconda3\lib\site-packages\nbconvert\postprocessors\base.py", line 28, in __call__
#     self.postprocess(input)
#   File "C:\Users\img44\anaconda3\lib\site-packages\nbconvert\postprocessors\serve.py", line 90, in postprocess
#     http_server.listen(self.port, address=self.ip)
#   File "C:\Users\img44\anaconda3\lib\site-packages\tornado\tcpserver.py", line 151, in listen
#     sockets = bind_sockets(port, address=address)
#   File "C:\Users\img44\anaconda3\lib\site-packages\tornado\netutil.py", line 161, in bind_sockets
#     sock.bind(sockaddr)
# OSError: [WinError 10048] Only one usage of each socket address (protocol/network address/port) is normally permitted
